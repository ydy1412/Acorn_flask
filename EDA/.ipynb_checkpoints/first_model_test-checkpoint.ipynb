# %%
import pandas as pd
import plotly as ply
import numpy as np
import matplotlib.pyplot as plt
from user_defined_function.functions import *
from IPython.display import clear_output

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_yaml

from xgboost import XGBClassifier

from sklearn.model_selection import train_test_split
from sklearn import metrics

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

image_directory= 'image_folder/'
data_directory = 'Original_data/survey_results_public.csv'

# %%
class PlotLosses(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []        
        self.fig = plt.figure()                
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.i += 1
        
        clear_output(wait=True)
        plt.plot(self.x, self.losses, label="loss")
        plt.legend()
        plt.show();
        
plot_losses = PlotLosses()

# %% [markdown]
# ### load original data

# %%
df = pd.read_csv(data_directory)
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  ... StackOverflowMakeMoney Gender  \
# 0                       NaN  ...      Strongly disagree   Male
# 1        20 to 99 employees  ...      Strongly disagree   Male
# 2  10,000 or more employees  ...               Disagree   Male
# 3  10,000 or more employees  ...               Disagree   Male
# 4        10 to 19 employees  ...                    NaN    NaN
#
#   HighestEducationParents                          Race         SurveyLong  \
# 0             High school  White or of European descent  Strongly disagree
# 1       A master's degree  White or of European descent     Somewhat agree
# 2   A professional degree  White or of European descent     Somewhat agree
# 3       A doctoral degree  White or of European descent              Agree
# 4                     NaN                           NaN                NaN
#
#   QuestionsInteresting QuestionsConfusing InterestedAnswers    Salary  \
# 0       Strongly agree           Disagree    Strongly agree       NaN
# 1       Somewhat agree           Disagree    Strongly agree       NaN
# 2                Agree           Disagree             Agree  113750.0
# 3                Agree     Somewhat agree    Strongly agree       NaN
# 4                  NaN                NaN               NaN       NaN
#
#    ExpectedSalary
# 0             NaN
# 1         37500.0
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 154 columns]

# %%
df[Rank2_feature[0]].unique()
# Out:
# array(['Very important', nan, 'Somewhat important', 'Important',
#        'Not very important', 'Not at all important'], dtype=object)

# %%
### Input column 과 output column에 대해 분석
Rank_feature = ['ProblemSolving','BuildingThings','LearningNewTech','BoringDetails',
                'JobSecurity','DiversityImportant','AnnoyingUI','FriendsDevelopers','RightWrongWay',
                'UnderstandComputers','SeriousWork','InvestTimeTools','WorkPayCare','ChallengeMyself','CompetePeers','ChangeWorld',
               ]
# array(['Strongly agree', nan, 'Agree', 'Somewhat agree', 'Disagree',
#        'Strongly disagree'], dtype=object)
Rank2_feature = ['AssessJobRole','AssessJobRemote','AssessJobProduct','AssessJobProfDevel',
                 'ImportantHiringEducation','ImportantHiringCommunication']
# array(['Very important', nan, 'Somewhat important', 'Important',
#        'Not very important', 'Not at all important'], dtype=object)
Nomial_feature = ['FormalEducation','MajorUndergrad','EducationTypes','ImportantBenefits']
total_input_features = Rank_feature+Rank2_feature+Nomial_feature
Output_feature =  ['Developer type']
Information_feature = ['CousinEducation']
### 인코딩이 필요한 칼럼 
Hot_encoding_needed = ['EducationTypes','CousinEducation','ImportantBenefits']

# %%
total_input_features = Rank_feature+Rank2_feature+Nomial_feature
total_input_features
# Out:
# ['ProblemSolving',
#  'BuildingThings',
#  'LearningNewTech',
#  'BoringDetails',
#  'JobSecurity',
#  'DiversityImportant',
#  'AnnoyingUI',
#  'FriendsDevelopers',
#  'RightWrongWay',
#  'UnderstandComputers',
#  'SeriousWork',
#  'InvestTimeTools',
#  'WorkPayCare',
#  'ChallengeMyself',
#  'CompetePeers',
#  'ChangeWorld',
#  'AssessJobRole',
#  'AssessJobRemote',
#  'AssessJobProduct',
#  'AssessJobProfDevel',
#  'ImportantHiringEducation',
#  'ImportantHiringCommunication',
#  'FormalEducation',
#  'MajorUndergrad',
#  'EducationTypes',
#  'ImportantBenefits']

# %%
EducationTypes_df = Hot_encoding(df,'EducationTypes',dropna = False)
EducationTypes_df.to_csv('Dataframe_folder/EducationTypes_df_HE.csv')
ImportantBenefits_df = Hot_encoding(df,'ImportantBenefits',dropna = False)
ImportantBenefits_df.to_csv('Dataframe_folder/ImportantBenefits_df_HE.csv')
CousinEducation_df = Hot_encoding(df,'CousinEducation',dropna = False)
CousinEducation_df.to_csv('Dataframe_folder/CousinEducation_df_HE.csv')
# Out:
# HBox(children=(IntProgress(value=0, max=51392), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=51392), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=51392), HTML(value='')))

# %%
Output_data = pd.read_csv('Dataframe_folder/DeveloperType_HE.csv',index_col = 0)
Output_data = Output_data[Output_data.sum(axis = 1)==1]
Output_data.sum(axis = 0)
# Out:
# Desktop applications developer                            1433
# Embedded applications/devices developer                    664
# Mobile developer                                          1556
# DevOps specialist                                          192
# Web developer                                            10683
# Other                                                     1174
# Database administrator                                      73
# Systems administrator                                       31
# Graphic designer                                             6
# Developer with a statistics or mathematics background      485
# Data scientist                                             249
# Graphics programming                                        55
# Quality assurance engineer                                 102
# Machine learning specialist                                 44
# dtype: int64

# %%
Output_data = Output_data[['Mobile developer','Web developer','Desktop applications developer']]
Output_data = Output_data[Output_data.sum(axis = 1)==1]
Output_data.shape
# Out:
# (13672, 3)

# %%
EducationTypes_df = pd.read_csv('Dataframe_folder/EducationTypes_df_HE.csv',index_col = 0)
ImportantBenefits_df = pd.read_csv('Dataframe_folder/ImportantBenefits_df_HE.csv',index_col = 0)
Dummy_df = dict()
for feature in total_input_features:
    Dummy_df[feature] = pd.get_dummies(df[feature])
Dummy_df['EducationTypes'] = EducationTypes_df
Dummy_df['ImportantBenefits'] = ImportantBenefits_df

# %%
for key in Dummy_df.keys():
    Dummy_df[key] = Dummy_df[key].loc[Output_data.index]

# %%
Dummy_df
# Out:
# {'ProblemSolving':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               0               1                  0
#  16         1         0               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      1         0               0               0                  0
#  51377      0         0               0               0                  0
#  51382      0         0               0               1                  0
#  51384      0         0               0               1                  0
#
#  [13672 rows x 5 columns],
#  'BuildingThings':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               0               1                  0
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      0         0               0               1                  0
#  51384      0         0               0               1                  0
#
#  [13672 rows x 5 columns],
#  'LearningNewTech':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               0               1                  0
#  16         1         0               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      1         0               0               0                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'BoringDetails':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         1               0               0                  0
#  16         0         0               0               0                  1
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      0         0               1               0                  0
#  51384      0         0               1               0                  0
#
#  [13672 rows x 5 columns],
#  'JobSecurity':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               1               0                  0
#  16         1         0               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      0         0               1               0                  0
#
#  [13672 rows x 5 columns],
#  'DiversityImportant':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               0               0                  1
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               1               0                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'AnnoyingUI':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      0         0               0               1                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'FriendsDevelopers':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         1               0               0                  0
#  16         0         0               0               0                  1
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'RightWrongWay':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         0         1               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         1               0               0                  0
#  51377      0         0               0               0                  0
#  51382      0         0               1               0                  0
#  51384      0         0               0               0                  1
#
#  [13672 rows x 5 columns],
#  'UnderstandComputers':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         1               0               0                  0
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      1         0               0               0                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      0         1               0               0                  0
#
#  [13672 rows x 5 columns],
#  'SeriousWork':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               1               0                  0
#  51377      0         0               0               0                  0
#  51382      0         0               0               1                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'InvestTimeTools':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         1         0               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'WorkPayCare':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               1               0                  0
#  16         0         0               0               0                  1
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               0                  1
#  51377      0         0               0               0                  0
#  51382      0         0               0               0                  1
#  51384      0         0               1               0                  0
#
#  [13672 rows x 5 columns],
#  'ChallengeMyself':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         1         0               0               0                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         0               0               1                  0
#  51377      0         0               0               0                  0
#  51382      0         0               0               1                  0
#  51384      1         0               0               0                  0
#
#  [13672 rows x 5 columns],
#  'CompetePeers':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         0         0               1               0                  0
#  16         0         0               0               0                  1
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      1         0               0               0                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      0         1               0               0                  0
#
#  [13672 rows x 5 columns],
#  'ChangeWorld':        Agree  Disagree  Somewhat agree  Strongly agree  Strongly disagree
#  7          0         0               0               0                  0
#  11         0         0               0               0                  0
#  13         0         0               0               0                  0
#  15         1         0               0               0                  0
#  16         0         0               0               1                  0
#  ...      ...       ...             ...             ...                ...
#  51372      0         0               0               0                  0
#  51374      0         1               0               0                  0
#  51377      0         0               0               0                  0
#  51382      1         0               0               0                  0
#  51384      0         0               1               0                  0
#
#  [13672 rows x 5 columns],
#  'AssessJobRole':        Important  Not at all important  Not very important  \
#  7              1                     0                   0
#  11             0                     0                   0
#  13             1                     0                   0
#  15             0                     0                   1
#  16             0                     0                   1
#  ...          ...                   ...                 ...
#  51372          1                     0                   0
#  51374          0                     0                   0
#  51377          0                     0                   0
#  51382          0                     0                   1
#  51384          1                     0                   0
#
#         Somewhat important  Very important
#  7                       0               0
#  11                      0               0
#  13                      0               0
#  15                      0               0
#  16                      0               0
#  ...                   ...             ...
#  51372                   0               0
#  51374                   1               0
#  51377                   0               1
#  51382                   0               0
#  51384                   0               0
#
#  [13672 rows x 5 columns],
#  'AssessJobRemote':        Important  Not at all important  Not very important  \
#  7              0                     0                   0
#  11             0                     0                   0
#  13             1                     0                   0
#  15             0                     0                   0
#  16             1                     0                   0
#  ...          ...                   ...                 ...
#  51372          0                     0                   0
#  51374          0                     0                   0
#  51377          0                     0                   0
#  51382          0                     0                   1
#  51384          0                     0                   0
#
#         Somewhat important  Very important
#  7                       1               0
#  11                      0               0
#  13                      0               0
#  15                      0               1
#  16                      0               0
#  ...                   ...             ...
#  51372                   1               0
#  51374                   1               0
#  51377                   1               0
#  51382                   0               0
#  51384                   1               0
#
#  [13672 rows x 5 columns],
#  'AssessJobProduct':        Important  Not at all important  Not very important  \
#  7              0                     0                   0
#  11             0                     0                   0
#  13             1                     0                   0
#  15             1                     0                   0
#  16             0                     0                   0
#  ...          ...                   ...                 ...
#  51372          0                     1                   0
#  51374          0                     0                   0
#  51377          0                     0                   1
#  51382          0                     0                   0
#  51384          0                     0                   0
#
#         Somewhat important  Very important
#  7                       1               0
#  11                      0               0
#  13                      0               0
#  15                      0               0
#  16                      0               1
#  ...                   ...             ...
#  51372                   0               0
#  51374                   1               0
#  51377                   0               0
#  51382                   1               0
#  51384                   1               0
#
#  [13672 rows x 5 columns],
#  'AssessJobProfDevel':        Important  Not at all important  Not very important  \
#  7              1                     0                   0
#  11             0                     0                   0
#  13             1                     0                   0
#  15             0                     0                   0
#  16             1                     0                   0
#  ...          ...                   ...                 ...
#  51372          0                     0                   0
#  51374          0                     0                   0
#  51377          1                     0                   0
#  51382          0                     0                   0
#  51384          0                     0                   0
#
#         Somewhat important  Very important
#  7                       0               0
#  11                      0               0
#  13                      0               0
#  15                      1               0
#  16                      0               0
#  ...                   ...             ...
#  51372                   1               0
#  51374                   0               1
#  51377                   0               0
#  51382                   1               0
#  51384                   0               1
#
#  [13672 rows x 5 columns],
#  'ImportantHiringEducation':        Important  Not at all important  Not very important  \
#  7              0                     0                   0
#  11             0                     0                   0
#  13             0                     0                   1
#  15             0                     0                   1
#  16             0                     0                   0
#  ...          ...                   ...                 ...
#  51372          0                     0                   0
#  51374          0                     0                   0
#  51377          0                     0                   0
#  51382          0                     0                   0
#  51384          1                     0                   0
#
#         Somewhat important  Very important
#  7                       1               0
#  11                      0               0
#  13                      0               0
#  15                      0               0
#  16                      0               0
#  ...                   ...             ...
#  51372                   1               0
#  51374                   0               0
#  51377                   0               1
#  51382                   0               0
#  51384                   0               0
#
#  [13672 rows x 5 columns],
#  'ImportantHiringCommunication':        Important  Not at all important  Not very important  \
#  7              1                     0                   0
#  11             0                     0                   0
#  13             1                     0                   0
#  15             0                     0                   0
#  16             0                     0                   0
#  ...          ...                   ...                 ...
#  51372          0                     0                   0
#  51374          0                     0                   0
#  51377          0                     0                   0
#  51382          0                     0                   0
#  51384          0                     0                   0
#
#         Somewhat important  Very important
#  7                       0               0
#  11                      0               0
#  13                      0               0
#  15                      1               0
#  16                      0               0
#  ...                   ...             ...
#  51372                   1               0
#  51374                   0               0
#  51377                   0               1
#  51382                   0               0
#  51384                   0               1
#
#  [13672 rows x 5 columns],
#  'FormalEducation':        Bachelor's degree  Doctoral degree  \
#  7                      0                0
#  11                     1                0
#  13                     0                0
#  15                     0                0
#  16                     0                0
#  ...                  ...              ...
#  51372                  0                0
#  51374                  1                0
#  51377                  1                0
#  51382                  0                0
#  51384                  1                0
#
#         I never completed any formal education  I prefer not to answer  \
#  7                                           0                       0
#  11                                          0                       0
#  13                                          0                       0
#  15                                          0                       0
#  16                                          0                       0
#  ...                                       ...                     ...
#  51372                                       0                       0
#  51374                                       0                       0
#  51377                                       0                       0
#  51382                                       0                       0
#  51384                                       0                       0
#
#         Master's degree  Primary/elementary school  Professional degree  \
#  7                    1                          0                    0
#  11                   0                          0                    0
#  13                   0                          0                    0
#  15                   0                          1                    0
#  16                   0                          0                    0
#  ...                ...                        ...                  ...
#  51372                0                          0                    0
#  51374                0                          0                    0
#  51377                0                          0                    0
#  51382                1                          0                    0
#  51384                0                          0                    0
#
#         Secondary school  \
#  7                     0
#  11                    0
#  13                    0
#  15                    0
#  16                    1
#  ...                 ...
#  51372                 1
#  51374                 0
#  51377                 0
#  51382                 0
#  51384                 0
#
#         Some college/university study without earning a bachelor's degree
#  7                                                      0
#  11                                                     0
#  13                                                     1
#  15                                                     0
#  16                                                     0
#  ...                                                  ...
#  51372                                                  0
#  51374                                                  0
#  51377                                                  0
#  51382                                                  0
#  51384                                                  0
#
#  [13672 rows x 9 columns],
#  'MajorUndergrad':        A business discipline  A health science  A humanities discipline  \
#  7                          0                 0                        0
#  11                         0                 0                        0
#  13                         0                 0                        0
#  15                         0                 0                        0
#  16                         0                 0                        0
#  ...                      ...               ...                      ...
#  51372                      0                 0                        0
#  51374                      0                 0                        0
#  51377                      0                 0                        0
#  51382                      0                 0                        0
#  51384                      0                 0                        0
#
#         A natural science  A non-computer-focused engineering discipline  \
#  7                      0                                              0
#  11                     0                                              0
#  13                     0                                              0
#  15                     0                                              0
#  16                     0                                              0
#  ...                  ...                                            ...
#  51372                  0                                              0
#  51374                  0                                              0
#  51377                  0                                              0
#  51382                  0                                              0
#  51384                  0                                              0
#
#         A social science  \
#  7                     0
#  11                    0
#  13                    0
#  15                    0
#  16                    0
#  ...                 ...
#  51372                 0
#  51374                 0
#  51377                 0
#  51382                 0
#  51384                 0
#
#         Computer engineering or electrical/electronics engineering  \
#  7                                                      0
#  11                                                     0
#  13                                                     0
#  15                                                     0
#  16                                                     0
#  ...                                                  ...
#  51372                                                  0
#  51374                                                  0
#  51377                                                  0
#  51382                                                  0
#  51384                                                  0
#
#         Computer programming or Web development  \
#  7                                            0
#  11                                           0
#  13                                           0
#  15                                           0
#  16                                           0
#  ...                                        ...
#  51372                                        0
#  51374                                        0
#  51377                                        0
#  51382                                        0
#  51384                                        1
#
#         Computer science or software engineering  Fine arts or performing arts  \
#  7                                             1                             0
#  11                                            1                             0
#  13                                            1                             0
#  15                                            0                             0
#  16                                            0                             0
#  ...                                         ...                           ...
#  51372                                         0                             0
#  51374                                         1                             0
#  51377                                         1                             0
#  51382                                         1                             0
#  51384                                         0                             0
#
#         I never declared a major  \
#  7                             0
#  11                            0
#  13                            0
#  15                            0
#  16                            0
#  ...                         ...
#  51372                         0
#  51374                         0
#  51377                         0
#  51382                         0
#  51384                         0
#
#         Information technology, networking, or system administration  \
#  7                                                      0
#  11                                                     0
#  13                                                     0
#  15                                                     0
#  16                                                     0
#  ...                                                  ...
#  51372                                                  0
#  51374                                                  0
#  51377                                                  0
#  51382                                                  0
#  51384                                                  0
#
#         Management information systems  Mathematics or statistics  Psychology  \
#  7                                   0                          0           0
#  11                                  0                          0           0
#  13                                  0                          0           0
#  15                                  0                          0           0
#  16                                  0                          0           0
#  ...                               ...                        ...         ...
#  51372                               0                          0           0
#  51374                               0                          0           0
#  51377                               0                          0           0
#  51382                               0                          0           0
#  51384                               0                          0           0
#
#         Something else
#  7                   0
#  11                  0
#  13                  0
#  15                  0
#  16                  0
#  ...               ...
#  51372               0
#  51374               0
#  51377               0
#  51382               0
#  51384               0
#
#  [13672 rows x 16 columns],
#  'EducationTypes':        Self-taught  Bootcamp  Industry certification  \
#  7                1         0                       0
#  11               0         0                       0
#  13               1         0                       0
#  15               0         0                       0
#  16               1         1                       1
#  ...            ...       ...                     ...
#  51372            1         1                       0
#  51374            1         0                       0
#  51377            0         0                       0
#  51382            1         0                       0
#  51384            1         0                       0
#
#         Open source contributions  Coding competition  On-the-job training  \
#  7                              1                   1                    1
#  11                             0                   0                    0
#  13                             1                   1                    1
#  15                             0                   0                    0
#  16                             1                   1                    1
#  ...                          ...                 ...                  ...
#  51372                          0                   0                    0
#  51374                          0                   0                    1
#  51377                          0                   0                    0
#  51382                          0                   0                    0
#  51384                          0                   0                    1
#
#         Online course  Hackathon  Part-time/evening course
#  7                  1          1                         0
#  11                 0          0                         0
#  13                 0          1                         1
#  15                 0          0                         0
#  16                 1          1                         0
#  ...              ...        ...                       ...
#  51372              0          1                         0
#  51374              0          1                         0
#  51377              0          0                         0
#  51382              0          0                         0
#  51384              0          0                         0
#
#  [13672 rows x 9 columns],
#  'ImportantBenefits':        Annual bonus  Other  Remote options  Charitable match  Stock options  \
#  7                 0      0               1                 0              0
#  11                0      0               0                 0              0
#  13                0      0               1                 0              1
#  15                0      0               1                 0              0
#  16                0      0               1                 0              0
#  ...             ...    ...             ...               ...            ...
#  51372             0      0               1                 0              0
#  51374             0      0               1                 0              0
#  51377             1      0               1                 0              0
#  51382             0      0               0                 0              0
#  51384             0      0               1                 0              0
#
#         Vacation/days off  Health benefits  Education sponsorship  \
#  7                      0                0                      0
#  11                     0                0                      0
#  13                     1                0                      0
#  15                     0                0                      0
#  16                     1                1                      0
#  ...                  ...              ...                    ...
#  51372                  0                0                      0
#  51374                  0                0                      0
#  51377                  0                0                      0
#  51382                  1                1                      0
#  51384                  1                0                      0
#
#         Long-term leave  None of these  Expected work hours  Private office  \
#  7                    0              0                    1               0
#  11                   0              0                    0               0
#  13                   0              0                    0               0
#  15                   0              0                    1               1
#  16                   0              0                    1               0
#  ...                ...            ...                  ...             ...
#  51372                0              0                    0               1
#  51374                0              0                    1               0
#  51377                0              0                    1               0
#  51382                0              0                    1               0
#  51384                0              0                    0               0
#
#         Professional development sponsorship  Retirement  Equipment  Meals  \
#  7                                         1           0          1      0
#  11                                        0           0          0      0
#  13                                        1           0          1      0
#  15                                        0           0          1      1
#  16                                        0           0          0      1
#  ...                                     ...         ...        ...    ...
#  51372                                     0           0          0      0
#  51374                                     1           0          0      0
#  51377                                     1           0          1      0
#  51382                                     0           1          0      1
#  51384                                     1           1          1      0
#
#         Child/elder care
#  7                     0
#  11                    0
#  13                    0
#  15                    0
#  16                    0
#  ...                 ...
#  51372                 0
#  51374                 0
#  51377                 0
#  51382                 0
#  51384                 0
#
#  [13672 rows x 17 columns]}

# %%
dummy_df_list = []
for key in Dummy_df.keys():
    dummy_df_list.append(Dummy_df[key])
Input_data = np.concatenate(dummy_df_list,axis = 1)

# %%
np.unique(np.argmax(Output_data.values,axis = 1),return_counts=True)
# Out:
# (array([0, 1, 2], dtype=int64), array([ 1556, 10683,  1433], dtype=int64))

# %%
labels = np.argmax(Output_data.values,axis = 1)

# %%
np.save("numpy_array_data/Input_data",Input_data)
np.save("numpy_array_data/label_data",labels)

# %%
trainX, testX, trainY, testY = train_test_split(Input_data, labels, test_size=0.2, random_state=42)

# %%
print("trainX :",trainX.shape)
print("trainX :",trainY.shape)
print("trainX :",testX.shape)
print("trainX :",testY.shape)
# Out:
# trainX : (10937, 161)
# trainX : (10937,)
# trainX : (2735, 161)
# trainX : (2735,)

# %%
def getModel(arr):
    model=Sequential()
    for i in range(len(arr)):
        if i!=0 and i!=len(arr)-1:
            if i==1:
                model.add(Dense(arr[i],input_dim=arr[0],kernel_initializer='normal', activation='relu'))
            else:
                model.add(Dense(arr[i],activation='relu'))
    model.add(Dense(arr[-1],kernel_initializer='normal',activation='softmax'))
    model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    # catego
    return model
Original_Model=getModel([161,50,3])

# %%
### Artificial neuron network 
firstModel.fit(np.array(trainX),np.array(trainY),epochs=40,callbacks=[plot_losses])
# Out:
# W1007 12:02:51.095944  4748 legend.py:1282] No handles with labels found to put in legend.

# %%
### XGBoost
XGBmodel = XGBClassifier()
XGBmodel.fit(trainX,trainY)
predictions = XGBmodel.predict(testX)

# %%
print ("accuracy" , metrics.accuracy_score(testY, predictions))
print(np.unique(testY,return_counts = True)[1][1]/np.sum(np.unique(testY,return_counts = True)[1]))
# Out:
# accuracy 0.7886654478976234
# 0.7886654478976234

# %%
np.unique(predictions,return_counts = True)
# Out:
# (array([1], dtype=int64), array([2735], dtype=int64))

# %%
# 0 = 'Mobile'
# 1 = 'Web'
# 2 = 'Desk'
Mobile =0
Web = 0
Desk = 0
np.unique(testY,return_counts = True)[1]
for i in range(predictions.shape[0]) :
    if testY[i] == predictions[i] :
        if testY[i] == 0 :
            Mobile += 1
        elif testY[i] == 1 :
            Web += 1
        else :
            Desk += 1
print("Mobile accuracy :", Mobile/np.unique(testY,return_counts = True)[1][0]*100)
print("Web accuracy :", Web/np.unique(testY,return_counts = True)[1][1]*100)
print("Desk accuracy :", Desk/np.unique(testY,return_counts = True)[1][2]*100)
# Out:
# Mobile accuracy : 0.0
# Web accuracy : 100.0
# Desk accuracy : 0.0

# %%
model_yaml = firstModel.to_yaml()
with open("Model_folder/ANN_model_unimbal.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# serialize weights to HDF5
firstModel.save_weights("Model_folder/model_3_unimbal.h5")

# %%
score = firstModel.evaluate(testX, testY, verbose=0)
score
# Out:
# [0.9268285886025298, 0.7378427788587986]

# %%
predY= firstModel.predict(testX)
unique_elements, counts_elements = np.unique(np.argmax(predY,axis = 1),return_counts=True)
print("predYunique_elements : ",unique_elements)
print("predY value's count : ",counts_elements)
print("real data value's count : ",np.unique(testY,return_counts = True))
# Out:
# predYunique_elements :  [0 1 2]
# predY value's count :  [ 133 2491  111]
# real data value's count :  (array([0, 1, 2], dtype=int64), array([ 304, 2157,  274], dtype=int64))

# %% [markdown]
# # 데이터가 비정형 데이터 이므로 under sampling, over sampling을 시행.

# %%
rus = RandomUnderSampler(random_state=0)
X_Undersample, y_Undersample = rus.fit_resample(Input_data, labels)
print("X_Undersample's shape : ",X_Undersample.shape)
print("y_Undersample's shape : ",y_Undersample.shape)
# Out:
# X_Undersample's shape :  (4299, 161)
# y_Undersample's shape :  (4299,)

# %%
ros = RandomOverSampler(random_state=0)
X_Oversample, y_Oversample = ros.fit_resample(Input_data,labels)
print("X_Undersample's shape : ",X_Oversample.shape)
print("y_Undersample's shape : ",y_Oversample.shape)
# Out:
# X_Undersample's shape :  (32049, 161)
# y_Undersample's shape :  (32049,)

# %% [markdown]
# # 먼저 Under sampling data를 이용하여 모델 테스트

# %%
UtrainX, UtestX, UtrainY, UtestY = train_test_split(X_Undersample, y_Undersample, test_size=0.2, random_state=42)
print("trainX :",UtrainX.shape)
print("trainX :",UtrainY.shape)
print("trainX :",UtestX.shape)
print("trainX :",UtestY.shape)
# Out:
# trainX : (3439, 161)
# trainX : (3439,)
# trainX : (860, 161)
# trainX : (860,)

# %%
### XGBoost
Unbal_XGBmodel = XGBClassifier()
Unbal_XGBmodel.fit(UtrainX,UtrainY)
Unbal_predictions = Unbal_XGBmodel.predict(UtestX)

# %%
# 0 = 'Mobile'
# 1 = 'Web'
# 2 = 'Desk'
Mobile =0
Web = 0
Desk = 0
np.unique(UtestY,return_counts = True)[1]
for i in range(Unbal_predictions.shape[0]) :
    if UtestY[i] == Unbal_predictions[i] :
        if UtestY[i] == 0 :
            Mobile += 1
        elif UtestY[i] == 1 :
            Web += 1
        else :
            Desk += 1
print("Mobile accuracy :", Mobile/np.unique(UtestY,return_counts = True)[1][0]*100)
print("Web accuracy :", Web/np.unique(UtestY,return_counts = True)[1][1]*100)
print("Desk accuracy :", Desk/np.unique(UtestY,return_counts = True)[1][2]*100)
# Out:
# Mobile accuracy : 50.641025641025635
# Web accuracy : 28.368794326241137
# Desk accuracy : 50.37593984962406

# %%
Unbal_Model=getModel([161,50,3])
Unbal_Model.fit(np.array(UtrainX),np.array(UtrainY),epochs=40,callbacks=[plot_losses])

# %%
# 생성된 모델 저장
model_yaml = Unbal_Model.to_yaml()
with open("Model_folder/ANN_model_under.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# serialize weights to HDF5
Unbal_Model.save_weights("Model_folder/model_3_under.h5")

# %%
predY= Unbal_Model.predict(testX)
unique_elements, counts_elements = np.unique(np.argmax(predY,axis = 1),return_counts=True)
print("predY unique_elements : ",unique_elements)
print("predY value's count : ",counts_elements)
print("real data value's count : ",np.unique(testY,return_counts=True))
# Out:
# predYunique_elements :  [0 1 2]
# predY value's count :  [941 973 821]
# real data value's count :  (array([0, 1, 2], dtype=int64), array([ 304, 2157,  274], dtype=int64))

# %% [markdown]
# #  Over sampling data를 이용하여 모델 테스트

# %%
OtrainX, OtestX, OtrainY, OtestY = train_test_split(X_Oversample, y_Oversample , test_size=0.2, random_state=42)
print("trainX :",OtrainX.shape)
print("trainX :",OtrainY.shape)
print("trainX :",OtestX.shape)
print("trainX :",OtestY.shape)
# Out:
# trainX : (25639, 161)
# trainX : (25639,)
# trainX : (6410, 161)
# trainX : (6410,)

# %%
Over_XGBmodel = XGBClassifier()
Over_XGBmodel.fit(OtrainX,OtrainY)
Over_predictions = Over_XGBmodel.predict(testX)

# %%
Mobile =0
Web = 0
Desk = 0
testY
for i in range(Over_predictions.shape[0]) :
    if testY[i] ==Over_predictions[i] :
        if testY[i] == 0 :
            Mobile += 1
        elif testY[i] == 1 :
            Web += 1
        else :
            Desk += 1
print("Mobile accuracy :", Mobile/np.unique(testY,return_counts = True)[1][0]*100)
print("Web accuracy :", Web/np.unique(testY,return_counts = True)[1][1]*100)
print("Desk accuracy :", Desk/np.unique(testY,return_counts = True)[1][2]*100)
# Out:
# Mobile accuracy : 60.526315789473685
# Web accuracy : 41.02920723226704
# Desk accuracy : 64.96350364963503

# %%
Over_Model=getModel([161,50,50,50,50,50,3])
Over_Model.fit(np.array(OtrainX),np.array(OtrainY),epochs=38,callbacks=[plot_losses])

# %%
# 생성된 모델 저장
model_yaml = Over_Model.to_yaml()
with open("Model_folder/ANN_model_over.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# serialize weights to HDF5
Over_Model.save_weights("Model_folder/model_3_over.h5")

# %%
score = Over_Model.evaluate(testX, testY, verbose=0)
score
# Out:
# [0.43700289734702225, 0.8453382084095064]

# %%
predY= Over_Model.predict(testX)
unique_elements, counts_elements = np.unique(np.argmax(predY,axis = 1),return_counts=True)
print("predYunique_elements : ",unique_elements)
print("predY value's count : ",counts_elements)
print("real data value's count : ",np.unique(testY,return_counts=True))
# Out:
# predYunique_elements :  [0 1 2]
# predY value's count :  [ 554 1777  404]
# real data value's count :  (array([0, 1, 2], dtype=int64), array([ 304, 2157,  274], dtype=int64))

# %%
print(np.argmax(predY,axis = 1))
print(testY)
Mobile =0
Web = 0
Desk = 0
testY
for i in range(predY.shape[0]) :
    if testY[i] == np.argmax(predY,axis = 1)[i] :
        if testY[i] == 0 :
            Mobile += 1
        elif testY[i] == 1 :
            Web += 1
        else :
            Desk += 1
print("Mobile accuracy :", Mobile/np.unique(testY,return_counts = True)[1][0]*100)
print("Web accuracy :", Web/np.unique(testY,return_counts = True)[1][1]*100)
print("Desk accuracy :", Desk/np.unique(testY,return_counts = True)[1][2]*100)
# Out:
# [1 1 1 ... 0 1 2]
# [1 1 1 ... 0 1 2]
# Mobile accuracy : 96.71052631578947
# Web accuracy : 81.8266110338433
# Desk accuracy : 92.33576642335767

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca_X  = pca.fit_transform(testX)

# %%
x = np.squeeze(pca_X[np.where(testY==0),0])
x.shape
# Out:
# (304,)

# %%
import plotly.graph_objects as go
import numpy as np

# Helix equation


fig = go.Figure()
x = np.squeeze(pca_X[np.where(testY==0),0])
y = np.squeeze(pca_X[np.where(testY==0),1])
z = np.squeeze(pca_X[np.where(testY==0),2])
fig.add_trace(go.Scatter3d(x=x, y=y, z=z,
                                   mode='markers',name = 'Mobile accuracy',marker = dict(size = 1,color = 0, line_color='rgb(140, 140, 170)')))
x = np.squeeze(pca_X[np.where(testY==1),0])
y = np.squeeze(pca_X[np.where(testY==1),1])
z = np.squeeze(pca_X[np.where(testY==1),2])
fig.add_trace(go.Scatter3d(x=x, y=y, z=z,
                                   mode='markers',name ='Web accuracy' ,marker = dict(size = 1,color = 100, line_color='rgb(140, 140, 170)')))
x = np.squeeze(pca_X[np.where(testY==2),0])
y = np.squeeze(pca_X[np.where(testY==2),1])
z = np.squeeze(pca_X[np.where(testY==2),2])
fig.add_trace(go.Scatter3d(x=x, y=y, z=z,
                                  mode='markers',name ='Desk accuracy' ,marker = dict(size = 1,color = 255, line_color='rgb(140, 140, 170)')))

fig.show()
# Out:
# <div>
#
#
#             <div id="5ab131f8-289a-489a-bb7f-f2575357de84" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5ab131f8-289a-489a-bb7f-f2575357de84")) {
#                     Plotly.newPlot(
#                         '5ab131f8-289a-489a-bb7f-f2575357de84',
#                         [{"marker": {"color": 0, "line": {"color": "rgb(140, 140, 170)"}, "size": 1}, "mode": "markers", "name": "Mobile accuracy", "type": "scatter3d", "x": [0.6010664466894374, 0.472098098048816, 1.0357665571972259, -1.431201132962993, -1.6955819449690932, -1.7221941811842685, -1.5749123849016649, 1.6983549885115072, 0.9225548297780733, 0.5714127105867788, 0.3272705509027774, -1.0383244385499746, -1.1309082061752955, 0.3368908858637546, -1.1093368422332412, 1.2158569941227755, 1.4400335451467245, 1.1047383030698081, 1.2325732230450175, 0.8806127537203715, 1.2551967467149312, 1.0276485352706886, 0.7431377961287315, -1.6968519305163992, 1.1132959314007673, -0.9456683584158713, 1.2196273624972318, 1.0630365197036762, -0.752440836445424, 0.9732046199470138, 0.8727473553720604, 0.9784073474245549, 0.7311609296486479, 0.2143632226264838, -1.6968519305163992, 1.1821503020587856, 0.9001813661944608, 0.21216639152338312, -1.4995374061274753, -1.3235694525307231, -1.0814852843022456, 1.1117372649298047, -1.0358804106964579, 1.694638012375511, -1.3626426919828354, -1.110892839412723, -1.722451944784154, 1.1064403017062159, -0.7376678025222193, 0.10748276175826187, -0.9574965439076468, 0.8456961642231828, 0.9166621507153736, 0.31586457082264746, 1.3934561805463763, 1.448435717065595, 0.9828319805806668, 1.0248632799848436, -0.9501798438565201, -1.4059955092761065, -1.2710524666821437, 0.6893587642613128, 1.4785604776130712, -0.41843446718126653, -1.3610694090271653, 0.3683088684304763, -1.3271409135937036, 0.8138185740067297, 0.5330802630870858, 0.40652528129071214, 0.1680757700346931, -1.0317847378133946, -1.6955819449690932, 1.4903702861315045, -1.697400281213088, -1.6955819449690932, 1.1397122381959914, -1.6955819449690932, 1.0985137172065262, 0.8976643124444909, 0.35821451713367836, -0.8746343594786177, 1.017793179855461, -1.2500995580247503, -0.9267146965384897, -1.1958940736958257, 1.1358856104780286, 1.0670501676719153, 1.38420960330668, -1.449209724717815, 1.6109463837660074, 0.30330459100228907, 0.2590331069853528, -1.0779787417679636, -1.5539278305748314, -0.7857632816476657, -0.012495218304068743, 0.9054478290359586, -1.1066514316083131, -1.0336336495839813, 1.038619011098513, 0.7249181840535879, -1.0207637348820537, 1.3229440826643322, -0.987338456350287, 1.2390583076305992, -1.2586124958290614, 0.6219753022960534, 0.7210989413871526, 0.7293297207150118, 1.2614508912688032, -1.3091368702935364, 1.6178260746769675, 0.65900082505318, -0.8822236217116499, -1.707742624152012, 0.9783386126177059, 1.785621452288171, 0.5842410000057112, 1.3824657063983699, 1.1634143217389672, -1.714785924661248, -1.7136709676092152, 0.8193481813777488, 0.10694916072210774, 1.0732676861492751, 0.35818143156563464, -1.7237219303314604, 0.6139884932953159, 0.8552409366910905, -1.6955819449690932, -1.704566206721492, 0.8001616045176516, 0.17097430026545468, 1.6322920870941926, 1.4643689812075285, 1.3602791053492755, 0.9770496158513645, -0.7732376207255615, 0.978370721770783, -0.21436049624895828, -1.2242696896223038, -1.1110969310223582, 1.294380931758272, 0.5390192983680823, 1.6359577390702602, -1.6968519305163992, -1.0738051613340767, 1.0462865116649858, 0.7281931260144956, 0.7623406507469294, 1.6202556827596228, -1.3169808574769222, -1.3998123760591437, 0.49322716306890124, 0.5685951294392626, 0.8629028074165452, -1.4670889211311071, 0.9128376735668429, 1.0252254160046146, 0.030407689819647678, -1.5115656446119887, 0.8879083553113988, 0.39573442986563445, 0.6861799622565776, 1.2035010029435966, -1.7074793308635745, -1.4916249491252849, 1.0926490416702406, 0.6448361767513754, -1.0291888437295256, -1.6968519305163992, -0.9809316205475246, -0.9934454747208358, 0.8990214058409897, 0.824625511192933, -1.5544858211903072, 0.9719859362841877, 0.49847760915137584, -1.6955819449690932, 1.1154290481355074, 0.523122970285909, -0.032442785340463354, 0.5985062872160664, -1.0426230655647375, -1.528076732238166, -1.710353825413474, -1.3399169449345 ...

# %%
pca_X[np.where(testY==0),0].shape
# Out:
# (1, 304)

# %%
x.shape
# Out:
# (100,)

# %%
# Load 하는 방법
yaml_file = open("Model_folder/ANN_model.yaml", 'r')
loaded_model_yaml = yaml_file.read()
yaml_file.close()
loaded_model = model_from_yaml(loaded_model_yaml)
# load weights into new model
loaded_model.load_weights("Model_folder/model.h5")
loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.dummy import DummyClassifier
from xgboost import XGBClassifier

# %%
class create_classification_df(x,y,models = ['SVM','NB','XGboost','KNeighbors','Logistic','SGD']
                             , performance = ['f1-score','recall','Accuracy','precise'], binomial = False) :
    
    def __init__(self, x,y,models = ['SVM','NB','XGboost','KNeighbors','Logistic','SGD']
                             , performance = ['f1-score','recall','Accuracy','precise'], binomial = False)):
        self.x = x
        self.y = y
        self.models = models
        self.performance = performance 
        self.binomial = binomial
        self.Set_xgboost_parameter()
    def Set_xgboost_parameter(self,objective = 'multi:softprob',eta = 0.1,max_depth = 5, num_class = 3, subsample = 0.8,
                             colsample_bytree = 0.8, eval_metric = 'mlogloss',min_child_weight= 10,reg_alpha = 1.5,
                             reg_lambda = 5, scale_pos_weight = 1, n_thread = -1) :
        if 'XGboost' in self.models :
            self.params = {'objective': objective,
                      'learning_rate':eta,
                      'max_depth': max_depth,
                      'num_class': num_class,
                      'subsample': subsample,
                      'colsample_bytree': colsample_bytree,
                      'eval_metric': eval_metric,
                      'min_child_weight': min_child_weight,
                      'reg_alpha': reg_alpha, 
                      'reg_lambda' : reg_lambda,
                      'scale_pos_weight' : scale_pos_weight,          
                      'n_thread':n_thread }
        else:
            print("no xgboost here")
  
    def construct_model(self) :
        model_dict = dict()
        if binomial == True:
            performance.append('AUC-ROC')
        for model in models :
            if model == 'SVM':
                model_dict[model] = SVC(kernel = 'rbf',random_state = 10)
            elif model == 'NB' :
                model_dict[model] = MultinomialNB()
            elif model == 'XGboost' :
                model_dict[model] = xgb.train(self.params,dtrain,n_rounds,early_stopping_rounds=early_stop,verbose_eval=10)

kf =StratifiedKFold(n_splits=5)
for train_index,test_index in kf.split(Input_data): 
    xtr,xvl = Input_data[train_index], Input_data[test_index]
    ytr,yvl = Output_data[train_index], Output_data[test_index]
    
    mNB.fit(xtr,ytr)
    y_mNB = mNB.predict(xvl)
    cv_score.append(log_loss(yvl,mNB.predict_proba(xvl)))    
    pred_test_full += mNB.predict_proba(X_test_cv)
